# %%
from XRStools import xrs_read, xrs_extraction
# Out:
#  >>>>>>>>  use_PyMca  True
#  >>>>>>>>  use_PyMca  True
# /Users/katherinegraves/opt/miniconda3/envs/xrstools-test2/lib/python2.7/site-packages/PyMca5/PyMcaGui/plotting/MaskImageWidget.pyc
#  Could not load PyTango
#  >>>>>>>>  use_PyMca  True
#
#  ############################# Welcome to XRStools #############################
#  # If you are using this software, please cite the following work:             #
#  # Ch.J. Sahle, A. Mirone, J. Niskanen, J. Inkinen, M. Krisch, and S. Huotari: #
#  # "Planning, performing, and analyzing X-ray Raman scattering experiments."   #
#  # Journal of Synchrotron Radiation 22, No. 2 (2015): 400-409.                 #
#  ###############################################################################

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
path = '/Users/katherinegraves/OneDrive - University of Leeds/PhD/Synchrotron/APS/Nov2019_NRIXS/XRSS/2019-11_20ID-APS/CNT-PS/'
#path = '/Users/katherinegraves/OneDrive - University of Leeds/PhD/Synchrotron/APS/Nov2019_NRIXS/XRSS/Luke_NIXS_2017/L_LA/'

# %%
myq = [2,5,8,9,10]

# %%
cnt = xrs_read.read_lerix(exp_dir=path,elastic_name='elastic',nixs_name='nixs',wide_name='wide')

# %%
# load all elastics, nixs and wides in one go
cnt.load_elastics(analyzers='all')
cnt.load_nixs()
cnt.load_wides()
# Out:
# Reading elastic scan:  elastic.0001
# Reading elastic scan:  elastic.0002
# Reading elastic scan:  elastic.0003
# Reading elastic scan:  elastic.0004
# Reading elastic scan:  elastic.0009
# Reading elastic scan:  elastic.0010
# Reading elastic scan:  elastic.0011
# Reading elastic scan:  elastic.0012
# Reading elastic scan:  elastic.0013
# Reading elastic scan:  elastic.0014
# Elastic scan is wrong shape, skipping
# Reading elastic scan:  elastic.0015
# Reading elastic scan:  elastic.0016
# Running 'Update_Cenom' Script for All analysers
# E0 was found to be (keV):  9.89036362323
# Average FWHM for the elastics is (eV):  nan
# Analyzer04 Elastic peak is less than 100 counts, setting to average e0
# Analyzer08 Elastic peak is less than 100 counts, setting to average e0
# Analyzer12 Elastic peak is less than 100 counts, setting to average e0
# Analyzer13 Elastic peak is less than 100 counts, setting to average e0
# Analyzer14 Elastic peak is less than 100 counts, setting to average e0
# Analyzer19 Elastic peak is less than 100 counts, setting to average e0
# Reading NIXS scan:  nixs.0001
# Reading NIXS scan:  nixs.0002
# Reading NIXS scan:  nixs.0003
# Reading NIXS scan:  nixs.0004
# Reading NIXS scan:  nixs.0005
# Reading NIXS scan:  nixs.0006
# Reading NIXS scan:  nixs.0007
# Reading NIXS scan:  nixs.0008
# Reading NIXS scan:  nixs.0009
# Reading NIXS scan:  nixs.0010
# Reading Wide scan:  wide.0001

# %%
wide_signals  = np.array([cnt.scans[cnt.scan_info(i)[1]].signals for i in cnt.wide_scans]).mean(axis=0)
wide_eloss    = np.array([cnt.scans[cnt.scan_info(i)[1]].eloss for i in cnt.wide_scans]).mean(axis=0)
wide_energy = np.array([cnt.scans[cnt.scan_info(i)[1]].energy  for i in cnt.wide_scans]).mean(axis=0)
wide_errors = np.array([cnt.scans[cnt.scan_info(i)[1]].errors  for i in cnt.wide_scans]).mean(axis=0)

# %%
np.all(np.diff(cnt.eloss) > 0)
# Out:
# True

# %%
np.all(np.diff(cnt.scans['nixs0002'].eloss) > 0)
# Out:
# True

# %%
cnt.eloss[86]
wide_eloss[86]
# Out:
# 260.8091067136229

# %%
# idx is boolean with len=wide_eloss, True when in the range of nixs_eloss
idx = (wide_eloss>=min(wide_eloss, key=lambda x:abs(x-min(cnt.eloss))))*(wide_eloss<=min(wide_eloss, key=lambda x:abs(x-max(cnt.eloss)))) 

# deletes wide_eloss values where False.
wide_eloss = np.delete(wide_eloss,np.where(idx)[0],axis=0)

# inserts nixs_eloss at the 0th value of idx
cnt.eloss = np.insert(wide_eloss,np.where(idx)[0][0],cnt.eloss,axis=0)

# %%
# tests whether the energies are strictly increasing
# TRUE if strictly increasing, FALSE if not
idx_remove = np.where(np.diff(cnt.eloss) < 0)
np.all(np.diff(cnt.eloss) > 0)
# Out:
# True

# %%
[cnt.eloss[85], cnt.eloss[86],cnt.eloss[87],cnt.eloss[88]]
# Out:
# [258.37133767629496, 259.4163572462952, 260.322509566295, 261.43745099629524]

# %%
cnt.eloss.shape # test shape of eloss axis (should be 505)
# Out:
# (504,)

# %%
# removes wide signal where there is nixs signal crossover
wide_signals_crossover = wide_signals[np.where(idx)[0][0]]
wide_signals = np.delete(wide_signals,np.where(idx)[0],axis=0)
wide_signals_crossover
# Out:
# array([ 6.96192484e-05,  3.83297009e-05,  8.36995479e-05,  1.87737315e-05,
#         2.34671634e-05,  2.86299381e-04,  1.32980596e-05,  2.03382075e-05,
#         4.86552527e-04,  1.52693007e-03,  9.93443250e-04,  5.94501465e-05,
#        -7.82238780e-07,  9.77798475e-05,  2.28413730e-04,  3.96595067e-04,
#         4.41182684e-04,  3.73127904e-04,  1.72092535e-05])

# %%
# SCALING VARIABLES BELOW

# %%
# IF SCALING = 'AUTO'
# divides wide signal by nixs signal at crossover point
# creates array of scaling values for each analyser
scaling_test = np.divide(wide_signals_crossover,cnt.signals[0])
scaling_test.shape # 19 due to the number of analysers
scaling_test
# Out:
# array([ 1.74449107,  1.38515985,  1.1369751 ,  1.28113868,  1.23483338,
#         0.80585377,  0.6074259 ,  0.68183733,  0.96530606,  0.9404909 ,
#         0.87913939,  1.13418535, -0.11633565,  0.86839536,  0.81724144,
#         0.98334175,  1.00955229,  0.91944988,  0.84128691])

# %%
# # find analysers thet have zero for scaling_test
# idx_remove = np.where(scaling_test == 0)[0]
# idx_remove
# # delete scaling from analysers that have zero values
# scaling_test = np.delete(scaling_test,idx_remove)
# scaling_test
# # delete signals for analysers that have zero for scaling_test wide and nixs
# cnt.signals = np.delete(cnt.signals,idx_remove,axis=1)
# wide_signals = np.delete(wide_signals,idx_remove,axis=1)

# %%
# TRY
# inserts the nixs scans to cut-out wide scans
test = np.insert(np.divide(wide_signals,scaling_test),np.where(idx)[0][0],cnt.signals,axis=0)
#test = np.insert(wide_signals,np.where(idx)[0][0],cnt.signals,axis=0)
test.shape
# Out:
# (504, 19)

# %%
#plot
plt.plot(cnt.eloss,test[:,2])
plt.plot(cnt.eloss,test[:,5])
plt.plot(cnt.eloss,test[:,8])
# plt.plot(cnt.eloss,test)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(cnt.eloss,cnt.signals[:,[2,5,8]]) #interactive plot window to look at each analyser output
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cnt.save_H5(H5name='PS_CNT_369_TAKE3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e16b82c2904a> in <module>()
# ----> 1 cnt.save_H5(H5name='PS_CNT_369_TAKE2')
#
# /Users/katherinegraves/OneDrive - University of Leeds/PhD/Code/XRStools-test2/XRStools/XRStools/xrs_read.pyc in save_H5(self, H5name)
#    3881         else:
#    3882             H5file = h5py.File(H5path, "w")
# -> 3883         g = H5file.create_group(H5name) #H5 subgroup with the name of the sample
#    3884         H5_ela = g.create_group('elastic') #H5 subgroup for elastics
#    3885         H5_xrs = g.create_group('XRS')     #H5 subgroup for NIXS
#
# /Users/katherinegraves/opt/miniconda3/envs/xrstools-test2/lib/python2.7/site-packages/h5py/_hl/group.pyc in create_group(self, name, track_order)
#      66             name, lcpl = self._e(name, lcpl=True)
#      67             gcpl = Group._gcpl_crt_order if track_order else None
# ---> 68             gid = h5g.create(self.id, name, lcpl=lcpl, gcpl=gcpl)
#      69             return Group(gid)
#      70
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5g.pyx in h5py.h5g.create()
#
# ValueError: Unable to create group (name already exists)

# %%
cnt.update_cenom(analyzers='all')

# %%
cnt_ex = xrs_extraction.edge_extraction(cnt,['C'],[1.0],{'C':['K']})

# %%
from XRStools import xrs_extraction

# %%
cnt_ex.analyzerAverage([2,5,8],errorweighing=False)

# %%
# %matplotlib
cnt_ex.removeCorePearsonAv('C','K',[115,283.0],[330.0,450.0],weights=[2,1],HFcore_shift=5.6,scaling=5.9)
# Out:
# Using matplotlib backend: nbAgg
# <img src="data:image/png;base64,..." width="640">
# The fit parameters are:  [-7.10219927e+01  1.10523262e+02  1.58239157e+00  4.03676179e+01
#   3.63420921e-05  2.91148181e-02  5.89410000e+00]

# %%
cnt_ex.save_average_Sqw(os.path.join(path,'PPCNT_data[369]_extract_BETTERSUBTRACT.dat'), emin=275,emax=340)

# %%
cnt_ex.sqwav
# Out:
# array([-7.77152158e-02, -1.67075856e+00, -1.88301166e+00, -1.82140068e+00,
#        -1.70266202e+00, -1.63345653e+00, -1.58166419e+00, -1.51479837e+00,
#        -1.48204356e+00, -1.34954199e+00, -1.27305350e+00, -1.19127270e+00,
#        -1.12213330e+00, -1.09187320e+00, -1.01330387e+00, -1.00120305e+00,
#        -9.35672081e-01, -9.09215604e-01, -8.43457706e-01, -8.27171839e-01,
#        -7.87877498e-01, -7.73447825e-01, -7.10691412e-01, -6.74516420e-01,
#        -6.51493383e-01, -5.88682498e-01, -5.47202835e-01, -5.06087598e-01,
#        -4.64772268e-01, -4.42073893e-01, -4.12172159e-01, -4.01663127e-01,
#        -3.67713715e-01, -3.84849219e-01, -3.38042139e-01, -3.25396885e-01,
#        -3.03457834e-01, -2.84674233e-01, -2.79149063e-01, -2.61662446e-01,
#        -2.35783842e-01, -2.20033970e-01, -2.27344761e-01, -2.19951276e-01,
#        -2.06975362e-01, -2.04279147e-01, -2.27274074e-01, -1.83128734e-01,
#        -1.64801973e-01, -1.75234752e-01, -1.34257258e-01, -1.54936892e-01,
#        -1.49012273e-01, -1.38781983e-01, -1.42360980e-01, -1.28082750e-01,
#        -1.27067986e-01, -1.11498322e-01, -1.35134362e-01, -1.19205102e-01,
#        -8.57831549e-02, -1.15187402e-01, -8.12805157e-02, -9.54542306e-02,
#        -8.68290199e-02, -7.92648719e-02, -5.85979538e-02, -9.09812622e-02,
#        -8.02899770e-02, -6.33937138e-02, -7.64150401e-02, -4.76055877e-02,
#        -4.97739283e-02, -4.50615604e-02, -3.87455889e-02, -4.28189565e-02,
#        -3.76667000e-02, -5.17348546e-02, -4.21141186e-02, -2.53805233e-02,
#        -2.99288704e-02, -3.41498467e-02, -2.74137571e-02, -1.57796871e-02,
#        -1.95875373e-02, -1.28629777e-02, -8.43237002e-03, -1.01699126e-02,
#        -8.14000486e-03, -6.29722590e-03, -4.51039422e-03, -5.03788543e-03,
#        -6.95024983e-03, -5.32587401e-03, -5.77499947e-03,  4.22140059e-05,
#         8.40042731e-05, -5.16958405e-03, -3.54176662e-03,  2.05399448e-03,
#         4.16901055e-03,  4.10808176e-04, -6.83142941e-04,  3.59174025e-03,
#         9.68680691e-12,  1.51699902e-03,  2.57387066e-03,  4.82051386e-03,
#         1.06874035e-03,  2.93297202e-03, -3.14339772e-04,  2.21456627e-04,
#         3.10909673e-04,  3.80919006e-04,  2.91831675e-03,  2.78421877e-03,
#         2.74104310e-03,  2.86449853e-03,  2.50571539e-03, -2.34521251e-04,
#         1.35682827e-03,  1.67923639e-03,  3.25247248e-03,  1.35134721e-03,
#         3.39344574e-04, -1.68109571e-03,  1.21796669e-03,  2.61038144e-03,
#         2.99574056e-03,  2.63120300e-03,  1.64489626e-03,  3.24870709e-03,
#         5.26347845e-04,  2.19562503e-03,  2.36907168e-03,  3.22244648e-03,
#         3.89891109e-03,  3.25769135e-03,  2.75355454e-03,  8.78044174e-04,
#         5.02727063e-03,  1.81641803e-03,  3.66761854e-03,  5.90019271e-03,
#         2.60574310e-03,  8.78072858e-04,  8.43947540e-03,  6.51730836e-03,
#         3.54978785e-03,  3.17692788e-03,  6.27026458e-03,  5.25839829e-03,
#         5.84473914e-03,  5.96770780e-03,  2.02405241e-03,  3.69670403e-03,
#         3.49790629e-03, -1.02581324e-03,  2.16787927e-03,  1.39755434e-03,
#         3.79465867e-03,  2.72780227e-03,  2.62043232e-03,  1.49978950e-03,
#         5.43359131e-03,  2.84613665e-03,  4.58986267e-03,  6.09147334e-03,
#         7.62952943e-03,  7.34583500e-03,  6.70531502e-03,  5.44439662e-03,
#         5.55551984e-03,  6.89005586e-03,  9.35034144e-03,  9.56240460e-03,
#         1.14230669e-02,  6.71976590e-03,  9.26981255e-03,  4.85969903e-03,
#         1.00921977e-02,  1.04008648e-02,  1.26014542e-02,  1.01983357e-02,
#         1.09220128e-02,  8.59513898e-03,  9.99028498e-03,  9.85500822e-03,
#         5.78030864e-03,  1.12131604e-02,  6.79496129e-03,  8.11378689e-03,
#         9.23993246e-03,  9.83765123e-03,  7.15639350e-03,  7.68447855e-03,
#         6.55029232e-03,  6.47540684e-03,  1.05702728e-02,  8.52273844e-03,
#         6.92612843e-03,  3.13325114e-03,  8.23836853e-03,  9.45743535e-03,
#         7.64113987e-03,  6.87565175e-03,  7.32259175e-03,  1.37000928e-02,
#         8.04698589e-03,  9.58663169e-03,  1.05198776e-02,  4.64186761e-03,
#         1.12160478e-02,  1.07631884e-02,  8.43747227e-03,  4.74566107e-03,
#         7.09190050e-03,  8.20233505e-03,  9.05657044e-03,  8.67594706e-03,
#         7.69783427e-03,  8.99763814e-03,  1.06920640e-02,  7.25872974e-03,
#         8.45911750e-03,  8.96567797e-03,  7.37382386e-03,  8.84426640e-03,
#         1.06901157e-02,  1.05936511e-02,  1.03218002e-02,  1.14369483e-02,
#         1.09547780e-02,  1.24753023e-02,  5.43832166e-03,  1.46830022e-02,
#         1.69279380e-02,  1.16174280e-02,  7.86099321e-03,  1.48867119e-02,
#         1.13057456e-02,  1.06317926e-02,  1.24718422e-02,  1.42570686e-02,
#         1.37526950e-02,  1.16035004e-02,  1.14992115e-02,  1.30397728e-02,
#         1.35228088e-02,  1.17190122e-02,  1.40171337e-02,  1.43136225e-02,
#         1.17539556e-02,  1.66991095e-02,  1.57417174e-02,  1.60182547e-02,
#         1.55615758e-02,  1.66467453e-02,  1.54837186e-02,  1.26517525e-02,
#         1.26517491e-02,  2.16886060e-02,  1.45787349e-02,  1.58676451e-02,
#         1.64192527e-02,  1.29271231e-02,  1.62613237e-02,  1.27875973e-02,
#         1.52792620e-02,  1.60954581e-02,  1.33361679e-02,  1.02976332e-02,
#         1.38819892e-02,  1.21903401e-02,  1.35861963e-02,  1.23683714e-02,
#         1.57677565e-02,  1.72038598e-02,  1.66348019e-02,  1.24344378e-02,
#         1.56228206e-02,  1.53930189e-02,  1.54193041e-02,  1.67873358e-02,
#         1.26685796e-02,  1.59964000e-02,  1.31014682e-02,  1.48828240e-02,
#         1.34453564e-02,  1.44923152e-02,  1.19998538e-02,  1.78006737e-02,
#         1.68521490e-02,  1.84552191e-02,  1.24985106e-02,  1.83168585e-02,
#         1.25857983e-02,  1.42098981e-02,  1.47212767e-02,  1.36303080e-02,
#         1.78483091e-02,  1.48503051e-02,  1.56856783e-02,  1.69316630e-02,
#         1.58325941e-02,  1.60298107e-02,  1.40654350e-02,  1.62159357e-02,
#         1.53650642e-02,  1.44790770e-02,  1.58260862e-02,  1.39636782e-02,
#         1.44746857e-02,  1.78097051e-02,  1.29697041e-02,  1.78837305e-02,
#         1.60903849e-02,  1.65191174e-02,  1.29352992e-02,  1.28887344e-02,
#         1.13408601e-02,  1.47434294e-02,  1.65643440e-02,  1.99814159e-02,
#         1.65051175e-02,  1.19684666e-02,  1.55245624e-02,  1.46484324e-02,
#         1.48721792e-02,  1.45852834e-02,  1.96512333e-02,  1.45681947e-02,
#         1.95498024e-02,  1.86648055e-02,  1.56603012e-02,  1.84357711e-02,
#         1.38466094e-02,  1.64581462e-02,  1.57436628e-02,  2.21353343e-02,
#         1.74735971e-02,  1.68626997e-02,  1.72503257e-02,  1.57123898e-02,
#         1.82077391e-02,  1.78128307e-02,  1.60368681e-02,  2.05417469e-02,
#         1.76873822e-02,  1.56597207e-02,  2.00371979e-02,  1.86047164e-02,
#         1.54511679e-02,  1.75291767e-02,  2.07788689e-02,  1.98001858e-02,
#         1.53513947e-02,  1.72464613e-02,  1.58909162e-02,  1.98152462e-02,
#         1.61586825e-02,  2.08154098e-02,  1.63360542e-02,  1.63241650e-02,
#         1.58623756e-02,  2.00421027e-02,  1.71581853e-02,  1.70503388e-02,
#         1.88795286e-02,  1.78780848e-02,  1.74562441e-02,  1.32800579e-02,
#         2.00690222e-02,  1.45805491e-02,  1.95617694e-02,  1.70171688e-02,
#         1.41348519e-02,  1.64137218e-02,  2.02104899e-02,  1.47063574e-02,
#         1.85198394e-02,  1.44537997e-02,  2.09259483e-02,  1.89021200e-02,
#         1.76626066e-02,  1.52912619e-02,  1.74528462e-02,  1.37584939e-02,
#         1.85791126e-02,  1.82568995e-02,  1.96239416e-02,  2.04914932e-02,
#         1.90381090e-02,  1.65798389e-02,  1.81095814e-02,  1.66226878e-02,
#         1.85577334e-02,  1.56538540e-02,  1.71444933e-02,  1.67719889e-02,
#         2.09997042e-02,  1.84694942e-02,  1.93432439e-02,  1.82031095e-02,
#         1.80119405e-02,  1.94895258e-02,  1.90213924e-02,  2.17164483e-02,
#         1.99643439e-02,  1.63225106e-02,  1.51303046e-02,  1.64259244e-02,
#         1.76181776e-02,  2.01537643e-02,  1.96595252e-02,  2.22020446e-02,
#         1.73034999e-02,  1.88990833e-02,  2.05458128e-02,  1.94447290e-02,
#         1.88876948e-02,  1.69002632e-02,  1.48273455e-02,  1.85087644e-02,
#         1.99783592e-02,  2.31566347e-02,  1.72798513e-02,  2.20891484e-02,
#         1.98926566e-02,  1.58050931e-02,  1.79829652e-02,  1.89748596e-02,
#         1.91886676e-02,  1.96305071e-02,  1.94323996e-02,  1.79318340e-02,
#         2.13290230e-02,  1.63683356e-02,  1.87073666e-02,  2.03977972e-02,
#         1.81809641e-02,  2.21441532e-02,  2.17952005e-02,  1.95890785e-02,
#         1.75019526e-02,  1.61923206e-02,  2.23446411e-02,  1.88612706e-02,
#         1.99162687e-02,  1.88231643e-02,  2.21321653e-02,  1.91948724e-02,
#         1.95348712e-02,  1.76183672e-02,  1.92707074e-02,  1.64059565e-02,
#         2.07535725e-02,  1.87924410e-02,  1.99714815e-02,  1.92326538e-02,
#         2.09790962e-02,  2.12494370e-02,  1.97641116e-02,  1.91983161e-02,
#         2.27012866e-02,  1.70138422e-02,  1.88352012e-02,  1.94618581e-02,
#         2.03839017e-02,  2.36569919e-02,  2.02300285e-02,  2.47651221e-02,
#         2.52332528e-02,  2.25453441e-02,  2.63785375e-02,  2.48619606e-02,
#         2.63091727e-02,  2.71141723e-02,  2.76214093e-02,  3.09536798e-02,
#         3.05146005e-02,  3.36948118e-02,  3.35481592e-02,  3.43901071e-02,
#         3.25210026e-02,  3.06734188e-02,  3.26717374e-02,  3.82996064e-02,
#         3.33736600e-02,  3.55905804e-02,  3.44569011e-02,  3.84185315e-02,
#         3.69992335e-02,  4.15128952e-02,  3.64666097e-02,  3.96471717e-02,
#         4.28274281e-02,  4.20747457e-02,  4.03140965e-02,  4.02741083e-02,
#         4.39437753e-02,  4.54492261e-02,  3.99780299e-02,  3.35748131e-02,
#         4.39903446e-02])
